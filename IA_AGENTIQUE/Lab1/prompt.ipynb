# %%
#La tokenisation avec Tiktoken#
import tiktoken
encoding = tiktoken.encoding_for_model("gpt-4o")
print(encoding.name)
# Out:
# o200k_base

# %%
system_message ="""
Perform Sentiment analysis of the review presented in the user message.
The result should be positive or negative. Do not justify your response
"""
tokens = encoding.encode(system_message)
print(len(tokens))
print(tokens)
for token in tokens:
   print(encoding.decode_single_token_bytes(token=token),end="")
# Out:
# 28
# [198, 73751, 31712, 2581, 8450, 328, 290, 3358, 13392, 306, 290, 1825, 3176, 558, 976, 1534, 1757, 413, 8841, 503, 12626, 13, 3756, 625, 14883, 634, 3322, 198]
# b'\n'b'Perform'b' Sent'b'iment'b' analysis'b' of'b' the'b' review'b' presented'b' in'b' the'b' user'b' message'b'.\n'b'The'b' result'b' should'b' be'b' positive'b' or'b' negative'b'.'b' Do'b' not'b' justify'b' your'b' response'b'\n'

# %%
def num_tokens_from_string(string: str, encoding_name: str = "o200k_base") ->int:
   """Returns the number of tokens in a text string."""
   encoding = tiktoken.get_encoding(encoding_name)
   num_tokens = len(encoding.encode(string))
   return num_tokens

num_tokens_from_string("tiktoken is great!")
# Out:
# 28
# [198, 73751, 31712, 2581, 8450, 328, 290, 3358, 13392, 306, 290, 1825, 3176, 558, 976, 1534, 1757, 413, 8841, 503, 12626, 13, 3756, 625, 14883, 634, 3322, 198]
# b'\n'b'Perform'b' Sent'b'iment'b' analysis'b' of'b' the'b' review'b' presented'b' in'b' the'b' user'b' message'b'.\n'b'The'b' result'b' should'b' be'b' positive'b' or'b' negative'b'.'b' Do'b' not'b' justify'b' your'b' response'b'\n'
# 6

# %%
#Comment formuler des prompts pour les LLM locaux avec Ollama#
from langchain_ollama import ChatOllama
llm = ChatOllama(model="llama3.2:3b")
response = llm.invoke([{"role": "system", "content": "You are a helpful assistant. The output should be in Markdown"},
  {"role": "user", "content": "C'est quoi un Agent AI"}])

# %%
from IPython.display import display, Markdown
print(display(Markdown(response.content)))
# Out:
# **Qu'est-ce qu'un Agent AI ?**
#
# Un agent AI (Agent Intelligent Artificiel) est un programme informatique conçu pour simuler les capacités de prise de décision et d'action d'une entité vivante, telle que l'être humain ou un animal. Il s'agit d'un composant clé du domaine de l'intelligence artificielle (IA).
#
# **Fonctionnement**
#
# Un agent AI est conçu pour répondre à une séquence d'événements et de situations dans son environnement, en utilisant une combinaison de techniques de recherche, de raisonnement et de modulation des actions. Il peut prendre en compte plusieurs facteurs tels que :
#
# * L'ambiance : les informations disponibles sur le monde extérieur
# * Les objectifs : les buts ou les cibles à atteindre
# * Les règles : les réglementations et les conditions contraintes applicables
#
# **Types d'agents AI**
#
# Existe-t-il plusieurs types d'agents AI, notamment :
#
# 1. **Agent à modèle**: il utilise un modèle de réseaux de neurones pour prendre des décisions
# 2. **Agent à règles**: il fonctionne en suivant une série de règles prédéfinies
# 3. **Agent à optimisation**: il recherche l'optimum d'une fonction ou d'un objectif
#
# **Exemples**
#
# Les agents AI sont utilisés dans de nombreux domaines, tels que :
#
# *   La robotique : les robots sont équipés d'agents pour prendre des décisions et effectuer des actions
# *   Le jeu vidéo : les agents sont utilisés pour créer des personnages intelligents capables de jouer à des jeux complexes
# *   Les systèmes d'intelligence artificielle : ils sont utilisés dans des applications telles que la reconnaissance vocale, la reconnaissance faciale et le traitement de langage naturel
# None

# %%
#Comment rédiger des instructions pour les LLMs Groq#
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
from langchain_groq import ChatGroq
llm2 = ChatGroq(model="openai/gpt-oss-120b",temperature=0.9)

# %%
from langchain.messages import SystemMessage, HumanMessage
from IPython.display import display, Markdown
resp2 = llm2.invoke([SystemMessage("You are a helpful assistant. The output should be in Mark-down"),
    HumanMessage("C'est quoi un Agent AI")
])
print(display(Markdown(resp2.content)))
# Out:
# ## Qu’est‑ce qu’un **Agent IA** ?
#
# Un **agent d’intelligence artificielle (IA)** est un logiciel (ou parfois un dispositif matériel) capable d’observer son environnement, de prendre des décisions et d’agir de façon autonome pour atteindre un ou plusieurs objectifs.
#
# ### 1. Principales caractéristiques d’un agent IA
# | Caractéristique | Description |
# |-----------------|-------------|
# | **Perception** | L’agent capte des informations via des capteurs (données d’entrée, webcam, microphones, API, etc.). |
# | **Raison / Traitement** | Il analyse ces données avec des modèles d’apprentissage (ML, deep learning, logique, planification, etc.) pour déterminer la meilleure action. |
# | **Action** | Il exécute une réponse (commande, texte, mouvement, recommandation, etc.) via des effecteurs (API, actionneur, interface utilisateur…). |
# | **Objectif** | Il possède un but (maximiser une récompense, accomplir une tâche, résoudre un problème). |
# | **Adaptabilité** | Il peut apprendre de nouvelles situations et s’ajuster en continu (apprentissage en ligne, renforcement, mise à jour de modèles). |
#
# ### 2. Types d’agents IA
#
# | Type d’agent | Exemple d’usage | Méthode d’apprentissage |
# |--------------|----------------|--------------------------|
# | **Agent réactif** | Chatbot simple, système de contrôle de trafic | Règles fixes, réseaux de neurones simples |
# | **Agent basé sur le modèle** | Assistant vocal qui garde le contexte d’une conversation | Modèles de langage (ex. GPT), bases de connaissances |
# | **Agent planificateur** | Robot de navigation autonome | Recherche de plan (A*, MCTS) + ML pour prédire coûts |
# | **Agent d’apprentissage par renforcement** | IA jouant à des jeux vidéo, optimisation de la logistique | Q‑learning, Deep Q‑Network, PPO, etc. |
# | **Agent multi‑agents** | Systèmes de trading automatisés, simulation de trafic | Interaction/coopération/compétition entre agents |
#
# ### 3. Architecture typique d’un agent IA
#
# ```
# +-------------------+
# |   Capteurs/Entrées|
# +--------+----------+
#          |
#          v
# +-------------------+      +-------------------+
# |   Perception      | ---> |   Représentation |
# +-------------------+      +-------------------+
#          |                         |
#          v                         v
# +-------------------+      +-------------------+
# |   Décision (Policy) |<--|   Modèle d’apprentissage |
# +-------------------+      +-------------------+
#          |
#          v
# +-------------------+
# |   Action/Sortie   |
# +-------------------+
# ```
#
# * **Perception** : pré‑traitement, extraction de caractéristiques.
# * **Modèle d’apprentissage** : réseau de neurones, arbres de décision, logique floue, etc.
# * **Policy / Décision** : fonction qui, à partir de l’état perçu, choisit l’action (souvent via une fonction de valeur ou directement par génération).
# * **Action** : envoi d’une commande, génération de texte, mouvement physique, etc.
#
# ### 4. Exemples concrets
#
# | Domaine | Agent IA | Fonctionnement |
# |--------|----------|----------------|
# | **Assistants vocaux** (Siri, Alexa) | Agent conversationnel | Capture audio → ASR (reconnaissance) → LLM → génération de réponse → synthèse vocale |
# | **Jeux vidéo** (AlphaGo, OpenAI Five) | Agent de jeu | Observes l’état du jeu → réseau de neurones + RL → sélection de la meilleure action |
# | **Véhicules autonomes** | Agent de conduite | Caméras, LIDAR → perception d’obstacles → planification de trajectoire → commande de direction et vitesse |
# | **Service client automatisé** | Chatbot IA | Analyse du texte du client → classification d’intention → réponse pré‑définie ou génération dynamique |
# | **Gestion d’énergie** | Agent de régulation | Capteurs de consommation → prédiction de la demande → optimisation du dispatch des ressources |
#
# ### 5. Pourquoi parler d’« agent » ?
#
# Le terme **agent** insiste sur la **capacité d’action autonome**. Contrairement à un simple modèle de prédiction (ex. un classifieur qui ne fait que renvoyer une étiquette), un agent :
#
# 1. **Interagit** avec son environnement (boucle perception‑action).
# 2. **Poursuit un objectif** (maximisation d’une récompense ou minimisation d’un coût).
# 3. **Peut s’adapter** en apprenant de nouvelles expériences.
#
# ### 6. Ressources pour aller plus loin
#
# | Ressource | Description |
# |-----------|-------------|
# | **Livre** : *Artificial Intelligence: A Modern Approach* (Russell & Norvig) | Chapitre 2 – Agents intelligents |
# | **Cours en ligne** : *CS50’s Introduction to AI* (Harvard) | Modules sur agents réactifs, agents basés sur le modèle et RL |
# | **Frameworks** | OpenAI Gym (environnements RL), Rasa (chatbot), ROS (robotique) |
# | **Article** : *Reinforcement Learning: An Introduction* (Sutton & Barto) | Fondamentaux du contrôle d’un agent via le RL |
#
# ---
#
# **En résumé** : un agent IA est un système capable de **percevoir**, **penser** et **agir** de façon autonome pour atteindre un but donné, en s’appuyant souvent sur des techniques d’apprentissage automatique. C’est le concept central derrière les assistants vocaux, les robots, les jeux vidéo intelligents et bien d’autres applications modernes.
# None

# %%
#Comment rédiger des instructions pour les LLMs OpenIA#
from langchain_openai import ChatOpenAI
load_dotenv(override=True)
model = ChatOpenAI(model="gpt-5.2", temperature=0)

# %%
response = model.invoke([
{"role":"system", "content":"You are a helpful assistant. The output should be in Markdown"},
{"role":"user","content":"C'est quoi un Agent AI"}
])

from IPython.display import display, Markdown
print(display(Markdown(response.content)))

# %%
#Exemple de prompt : analyse de sentiment basée sur les aspects#
system_message = """
Effectuez une analyse de sentiments basée sur les aspects des avis concernant
les ordinateurs portables présentés en entrée.

Chaque avis peut comporter un ou plusieurs des aspects suivants : screen, key-
bloard et pad.

Pour chaque avis présenté en entrée :
- Identifiez la présence d'au moins un des trois aspects (screen, keybloard,
pad).
- Attribuez une polarité de sentiment (positive, negative ou neutral) à chaque

aspect. Organisez votre réponse dans un objet JSON avec les en-têtes sui-
vants :

- category:[liste des aspects]
- polarity:[liste des polarités correspondantes pour chaque aspect]

Si l'un des aspects n'est pas présent dans l'avis de l'utilisateur, tu sup-
poses que la polarité est neutre

"""

# %%
llm = ChatOpenAI(
model="gpt-5.2",
temperature=0,
model_kwargs={
"response_format": {"type": "json_object"}
}
)
resp = llm.invoke([
{"role": "system", "content": system_message},
{"role": "user", "content": "L'écran est très bon, mais je n'ai pas aimé la souris. le clavier Ma fih Maytchaf"}
])
print(resp.content)

# %%
llm = ChatOpenAI(
model="gpt-5.2",
temperature=0,
model_kwargs={
"response_format": {"type": "json_object"}
}
)
resp = llm.invoke([
{"role": "system", "content": system_message},
{"role": "user", "content": "L'écran est très bon, mais je n'ai pas aimé la souris. le clavier Ma fih Maytchaf"}
])
print(resp.content)

# %%
#LLM Multi-Modal : génération d’image#
llm4 = ChatOpenAI(model="gpt-5.2")
llm_with_tools = llm4.bind_tools([
{"type":"image_generation", "quality":"high"}
])

resp4 = llm_with_tools.invoke(input=[
HumanMessage("Je veux une photo d'un chat qui code du java")
])

from IPython.display import Image
import base64

Image(base64.b64decode(resp4.content_blocks[0]['base64']))

# %%
#LLM Multi-Modal : Description d’image#
path ="rag.png"
Image(path)
llm5 = ChatOpenAI(model="gpt-5.2")

def encode_image(image_path):
with open(image_path, "rb") as image_file:
return base64.b64encode(image_file.read()).decode("utf-8")

img = encode_image(path)

resp5 = llm5.invoke(input=[
HumanMessage(content=[
{"type":"text","text":"Qu'est ce que tu vois dans cette image"},
{"type":"image_url", "image_url": {"url":
f"data:image/png;base64,{img}"}}
])])

print(display(Markdown(resp5.content)))
